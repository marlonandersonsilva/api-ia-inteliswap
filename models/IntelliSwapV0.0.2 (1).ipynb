# %% [markdown]
# # 📘 Seção 1: Instalações e Imports

# %%
# Instale as dependências necessárias
import requests
import pandas as pd
from datetime import datetime, timedelta
import pytz
import os
import plotly.express as px
import glob

# %% [markdown]
# # 🔐 Seção 2: Configuração do Endpoint da The Graph

# %%
API_KEY = "54b3ae486458761ae740097bf7665918"

GRAPHQL_URL = f"https://gateway.thegraph.com/api/{API_KEY}/subgraphs/id/5zvR82QoaXYFyDEKLZ9t6v9adgnptxYpKpSbxtgVENFV"

# %% [markdown]
# # 📡 Seção 3: Consulta das 5 maiores pools de liquidez

# %%
def get_top_5_pools():
    query = {
        "query": """
        {
          pools(orderBy: volumeUSD, orderDirection: desc, first: 5) {
            id,
            volumeUSD,
            feeTier,
            token0Price,
            token1Price,
            liquidity,
            token0 {
              symbol,
              id,
              decimals
            }
            token1 {
              symbol,
              id,
              decimals
            }
          }
        }
        """
    }
    response = requests.post(GRAPHQL_URL, json=query)
    response.raise_for_status()
    data = response.json()
    if "errors" in data:
        raise Exception(f"GraphQL error: {data['errors']}")
    return data["data"]["pools"]

# %% [markdown]
# # 📅 Seção 4 Buscar dados agregados dos últimos 30 dias para uma pool

# %%
def get_unix_timestamp_days_ago(days: int) -> int:
    dt = datetime.now(pytz.utc) - timedelta(days=days)
    return int(dt.timestamp())

def build_day_data_query(pool_id, start_timestamp):
    return {
        "query": f"""
        {{
          poolDayDatas(
            first: 1000,
            orderBy: date,
            orderDirection: desc,
            where: {{
              pool: "{pool_id}",
              date_gte: {start_timestamp}
            }}
          ) {{
            date
            volumeUSD
            tvlUSD
            feesUSD
            token0Price
            token1Price
            liquidity
          }}
        }}
        """
    }

def fetch_pool_day_data(pool_id):
    start_timestamp = get_unix_timestamp_days_ago(90)
    query = build_day_data_query(pool_id, start_timestamp)
    try:
        response = requests.post(GRAPHQL_URL, json=query)
        response.raise_for_status()
        data = response.json()
        if "errors" in data:
            raise Exception(f"GraphQL error: {data['errors']}")
        return data["data"]["poolDayDatas"]
    except requests.RequestException as e:
        print("Erro de requisição:", e)
    except Exception as e:
        print("Erro na resposta ou estrutura da API:", e)
    return []

# %% [markdown]
# # 🧮 Seção 5. Processar os dados em DataFrame

# %%
def process_data(raw_data, fee_tier):
    if not raw_data:
        return pd.DataFrame()

    df = pd.DataFrame(raw_data)
    df['date'] = pd.to_datetime(df['date'], unit='s')

    numeric_cols = ['volumeUSD', 'tvlUSD', 'feesUSD', 'token0Price', 'token1Price', 'liquidity']
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    df = df.sort_values("date")
    df['feeTier'] = fee_tier / 10000

    # Cálculo de APR diário (sem composição)
    df['dailyAPR'] = df.apply(
        lambda row: ((row['feesUSD'] / row['tvlUSD']) * 365 * 100) if row['tvlUSD'] > 0 else 0,
        axis=1
    )

    return df

# %% [markdown]
# # 💾 Seção 6. Executar tudo e salvar em CSV

# %%
output_dir = "pool_data_csv"
os.makedirs(output_dir, exist_ok=True)
top_pools = get_top_5_pools()
print("🔝 Top 5 Pools por volumeUSD:\n")

for i, pool in enumerate(top_pools):
    token0 = pool['token0']['symbol']
    token1 = pool['token1']['symbol']
    fee_raw = int(pool['feeTier'])
    fee_percent = fee_raw / 10000
    symbol = f"{token0}_{token1}"
    fee_str = f"{fee_percent:.2f}pct"
    pool_id = pool['id']
    print(f"{i+1}. {symbol} (fee: {fee_percent:.2f}%) - Pool ID: {pool_id}")

    raw_data = fetch_pool_day_data(pool_id)
    df = process_data(raw_data, fee_raw)

    if df.empty:
        print(f"⚠️ Nenhum dado para {symbol}")
        continue

    filename = f"{output_dir}/{pool_id}_{token0}_{token1}_{fee_str}_last90d.csv"
    df.to_csv(filename, index=False)
    print(f"✅ Dados salvos: {filename}")
# Out:
# 🔝 Top 5 Pools por volumeUSD:
#
# 1. USDC_WETH (fee: 0.05%) - Pool ID: 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# ✅ Dados salvos: pool_data_csv/0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640_USDC_WETH_0.05pct_last90d.csv
# 2. WETH_USDT (fee: 0.05%) - Pool ID: 0x11b815efb8f581194ae79006d24e0d814b7697f6
# ✅ Dados salvos: pool_data_csv/0x11b815efb8f581194ae79006d24e0d814b7697f6_WETH_USDT_0.05pct_last90d.csv
# 3. USDC_USDT (fee: 0.01%) - Pool ID: 0x3416cf6c708da44db2624d63ea0aaef7113527c6
# ✅ Dados salvos: pool_data_csv/0x3416cf6c708da44db2624d63ea0aaef7113527c6_USDC_USDT_0.01pct_last90d.csv
# 4. WBTC_WETH (fee: 0.05%) - Pool ID: 0x4585fe77225b41b697c938b018e2ac67ac5a20c0
# ✅ Dados salvos: pool_data_csv/0x4585fe77225b41b697c938b018e2ac67ac5a20c0_WBTC_WETH_0.05pct_last90d.csv
# 5. USDC_WETH (fee: 0.30%) - Pool ID: 0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8
# ✅ Dados salvos: pool_data_csv/0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8_USDC_WETH_0.30pct_last90d.csv

# %% [markdown]
# # 📈 Seção 7. Visualização Interativa dos Dados Agregados

# %%
def plot_metrics_from_csv(csv_path):
    df = pd.read_csv(csv_path)
    df['date'] = pd.to_datetime(df['date'])
    pool_name = os.path.basename(csv_path).replace('_last90d.csv', '')

    metrics = [
        ('volumeUSD', '📈 Volume Diário'),
        ('tvlUSD', '🔐 TVL Diário'),
        ('feesUSD', '💸 Taxas Diárias'),
        ('dailyAPY', '📊 APY Diário Estimado'),
        ('liquidity', '🧊 Liquidez Total'),
        ('token0Price', '💱 Preço do Token0'),
        ('token1Price', '💱 Preço do Token1'),
    ]

    for col, title in metrics:
        if col in df.columns:
            fig = px.line(df, x='date', y=col, title=f'{title} - {pool_name}', markers=True)
            fig.update_layout(xaxis_title='Data', yaxis_title=col)
            fig.show()

# %% [markdown]
# # 📂 Seção 8. Ler e Plotar Todos os Arquivos CSV

# %%
csv_files = glob.glob(f"{output_dir}/*_last90d.csv")
if not csv_files:
    print("❌ Nenhum arquivo CSV encontrado.")
else:
    for csv_file in csv_files:
        plot_metrics_from_csv(csv_file)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f522a7c-b420-4ad0-b30a-7b8f039056ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f522a7c-b420-4ad0-b30a-7b8f039056ae")) {                    Plotly.newPlot(                        "5f522a7c-b420-4ad0-b30a-7b8f039056ae",                        [{"hovertemplate":"date=%{x}\u003cbr\u003evolumeUSD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[16929259.448421232,14764661.084999142,4502606.432041932,5425682.3195376,23354808.74910964,16827506.228288542,10299795.01267028,16124556.102004772,35188938.02071858,8445945.831362562,11295868.252325894,43403857.763475865,55965422.20282177,26881763.885097302,7046627.733867507,12229194.39191539,3233521.137100832,54450828.07112483,21249553.348919436,45679766.23909402,37918431.90853932,43989725.82284344,75232881.37811948,22814005.95663732,39314616.21847356,78366923.38227822,41796449.28494134,25239838.98721145,6128171.431769935,6713553.302053883,4385709.876756359,5662729.049100153,9623285.972214526,4979996.772399356,23617983.98267642,12752256.269243762,7346968.9075606,3706207.87638956,4469574.19134792,12905459.8053363,9545163.299178565,10356764.544793377,7718673.8509291615,10519001.083992328,3290418.673226164,3031874.3687073137,3730361.5115662753,5714320.470019907,13192730.528127585,4158672.777947241,5282374.531320389,1478237.7200420587,32613580.414947297,25183262.997166608,4994560.879935784,10625448.622485884,29229370.528800733,19577940.16549749,11086705.805525804,19832907.100772347,17539626.93169907,11601050.07217927,19134883.771802794,8077759.808125619,2110307.36 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="593ef812-c041-4812-9d75-9651e17ebb39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("593ef812-c041-4812-9d75-9651e17ebb39")) {                    Plotly.newPlot(                        "593ef812-c041-4812-9d75-9651e17ebb39",                        [{"hovertemplate":"date=%{x}\u003cbr\u003etvlUSD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[310077405.1747,313660667.16094273,312196465.5674401,309975746.7359824,315208260.1878467,310372728.2005094,314090267.6217437,315295491.6671561,309968868.55264723,317492574.07086927,320873612.5193802,301055008.5163568,308227706.85890514,292057338.79537535,289996277.227742,286258644.51573205,284739549.1250775,306141515.11634374,281649617.7942013,309199287.9586644,316051227.3674001,314281727.9431612,309390628.6474222,314351455.37231,299965074.19552684,289209939.0019692,293816399.0910112,268134162.6825401,285997549.8308588,268714724.26832616,270660601.3260301,266432475.62556967,269720048.39058495,269865652.8147506,279085724.1932012,274360694.87116987,273492942.90843046,274513976.8774114,275867872.082549,281049155.76624525,280193261.37174475,276161890.8751677,276393580.2340169,268398200.271018,260007201.01013288,258539491.8265166,260660999.01995847,267004866.29770485,258856799.65499893,260147796.79972732,259956044.75738505,259196077.89822772,245624618.39412624,241487860.59255052,235631980.48694327,248889664.62726083,237643525.04592684,240661000.46251985,246104119.2486941,242834355.116818,244839194.7381139,242661369.95544928,242492572.9559366,242733434.90216905,24482376 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="71e1f0a1-0478-4cc2-9ae5-c1fece3525ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71e1f0a1-0478-4cc2-9ae5-c1fece3525ed")) {                    Plotly.newPlot(                        "71e1f0a1-0478-4cc2-9ae5-c1fece3525ed",                        [{"hovertemplate":"date=%{x}\u003cbr\u003efeesUSD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[50787.778345263694,44293.98325499743,13507.819296125794,16277.0469586128,70064.42624732893,50482.51868486562,30899.38503801084,48373.66830601432,105566.81406215574,25337.83749408768,33887.60475697768,130211.5732904276,167896.2666084653,80645.29165529192,21139.88320160252,36687.58317574617,9700.563411302495,163352.48421337447,63748.6600467583,137039.29871728207,113755.29572561797,131969.1774685303,225698.64413435844,68442.01786991196,117943.84865542066,235100.7701468347,125389.347854824,75719.51696163436,18384.514295309804,20140.659906161647,13157.129630269075,16988.18714730046,28869.85791664357,14939.990317198068,70853.95194802927,38256.768807731285,22040.9067226818,11118.62362916868,13408.72257404376,38716.379416008895,28635.48989753569,31070.293634380127,23156.021552787483,31557.003251976985,9871.256019678493,9095.62310612194,11191.084534698824,17142.96141005972,39578.19158438275,12476.018333841725,15847.123593961169,4434.713160126176,97840.74124484188,75549.78899149981,14983.682639807352,31876.34586745765,87688.11158640221,58733.82049649247,33260.117416577414,59498.72130231705,52618.88079509721,34803.15021653781,57404.65131540838,24233.27942437685,6330.922090 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c8a7e168-2cb1-42ff-a37f-bedb48182f0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8a7e168-2cb1-42ff-a37f-bedb48182f0b")) {                    Plotly.newPlot(                        "c8a7e168-2cb1-42ff-a37f-bedb48182f0b",                        [{"hovertemplate":"date=%{x}\u003cbr\u003eliquidity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[3.726755315857414e18,3.732762904846999e18,3.751358506071511e18,4.094230698549231e18,3.984114283717192e18,3.936527161167343e18,3.948307266523773e18,4.0123827660364017e18,3.960153622129473e18,3.655206767634887e18,3.683299557552825e18,3.647312639360054e18,5.102055918608265e18,7.380790012275028e17,7.455448981997261e17,6.21128479199804e17,6.212258633990716e17,4.852114273586871e18,6.099337918699476e17,5.564939189224544e18,5.648464252667084e18,5.745707851970218e18,6.147704671271029e18,5.767258923094511e18,5.578023255263486e18,4.906826763403648e17,5.711464037879204e18,9.636023837612569e18,1.640589781118925e20,4.2452726385262433e18,4.2439519675699374e18,8.176971918532037e17,4.291459457761445e18,4.316730855876877e18,4.3816562631180114e18,4.424543724387848e18,4.411382666544485e18,4.4372150395628897e18,4.528880085953128e18,4.5052459580402094e18,4.4947881170947584e18,4.59763209891272e18,4.6085121482793016e18,9.3076262767174e17,8.60181038385299e17,8.753967933227022e17,9.261060634501124e17,4.421768822070309e18,8.867714853265632e17,9.168021885251924e17,9.24680287600388e17,9.293417893723622e17,1.0829082476401812e18,4.578320318229399e17,4.539155750225808e17,5.302643054629504e17 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2fcbe6d7-4a19-4f34-a1ca-8e26a4128bf5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fcbe6d7-4a19-4f34-a1ca-8e26a4128bf5")) {                    Plotly.newPlot(                        "2fcbe6d7-4a19-4f34-a1ca-8e26a4128bf5",                        [{"hovertemplate":"date=%{x}\u003cbr\u003etoken0Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[2672.277442051196,2722.203383241482,2696.4802306415736,2661.713980731704,2743.2601862671263,2662.841550145263,2720.9446769304054,2738.931845902847,2654.180422334388,2769.45613950798,2824.4774742121326,2507.227197358972,2499.009066661537,2329.467990062953,2307.0342228587538,2232.104234531892,2212.1849962965807,2518.7691129386485,2148.6453313993998,2168.6526423453365,2244.395685872505,2207.191996356377,2134.8539518183093,2200.299677266059,2013.9599253803383,1864.818847243508,1922.8520192338108,1906.9048718022243,1866.2238354844253,1914.6209127724155,1942.76438236167,1883.133995675592,1928.1564438471544,1929.4871509567893,2062.7844945905404,1977.5170689789427,1967.5289417264005,1981.0569975220264,1999.973084207173,2075.395733167873,2063.763235770185,2004.5897590218071,2005.60256723594,1895.3859820912933,1824.066236413713,1802.3249909313413,1825.451276690372,1910.5488765104208,1798.1305292361149,1814.6019437670373,1814.5193623926684,1803.6231585347484,1575.1640599141442,1555.7770188639636,1468.9795477371383,1665.053220192996,1522.759433955385,1565.2588673658668,1646.8275896815503,1594.9834160471137,1623.339227888366,1590.162968043211,1578.0215522242454,1584.3265 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57fec67f-6c1c-4395-a664-57f828f23851" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57fec67f-6c1c-4395-a664-57f828f23851")) {                    Plotly.newPlot(                        "57fec67f-6c1c-4395-a664-57f828f23851",                        [{"hovertemplate":"date=%{x}\u003cbr\u003etoken1Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[0.0003742126413462,0.0003673494809962,0.0003708538221925,0.0003756977673931,0.0003645297682684,0.000375538679703,0.0003675194165021,0.0003651058355087,0.0003767641384079,0.0003610817249402,0.0003540477872916,0.000398846981659,0.0004001586122038,0.0004292825676359,0.0004334569422905,0.0004480077518466,0.0004520417603745,0.0003970193198189,0.0004654095235665,0.0004611158008774,0.0004455542337273,0.0004530643467585,0.0004684161177153,0.0004544835461879,0.0004965342097416,0.0005362451165045,0.0005200608211122,0.000524410008484,0.0005358414039012,0.0005222966036404,0.0005147304578357,0.0005310296571016,0.0005186301159281,0.0005182724329126,0.0004847816156377,0.0005056846363992,0.0005082517358664,0.0005047810341907,0.0005000067290387,0.0004818358176315,0.0004845517076123,0.0004988551874514,0.0004986032708255,0.0005275970221625,0.0005482257058636,0.0005548388914494,0.0005478097458799,0.0005234097972026,0.0005561331525942,0.0005510850483958,0.0005511101290654,0.0005544395431318,0.0006348545052853,0.0006427656327834,0.0006807446717283,0.0006005814035686,0.0006567025478229,0.0006388719596796,0.0006072281070985,0.000626965766502,0.0006160141902692,0.0006288663615595,0. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="effc7960-de06-43dd-885f-4140a8b17a38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("effc7960-de06-43dd-885f-4140a8b17a38")) {                    Plotly.newPlot(                        "effc7960-de06-43dd-885f-4140a8b17a38",                        [{"hovertemplate":"date=%{x}\u003cbr\u003evolumeUSD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[98510125.63306156,93542103.9041784,36964560.42077375,40314734.282873295,118869197.25078776,99441571.4958438,44768595.28659853,40126379.473984286,107282453.69316123,54571546.14046616,86715130.41606458,121897805.33685292,201439762.70818245,111498183.40013438,122577370.1177081,285561874.2376293,77384105.1034968,201949623.08477664,152586813.4806418,199429792.4503609,121523522.85918713,110206323.65540484,188448485.24307027,65216881.308192976,142597880.49122265,277037927.36386335,208095412.484579,142647117.12519786,97654182.55325784,53322059.94455509,26704500.028072447,41442520.29803342,42236250.84424984,46022739.78969594,84459374.10029884,55369527.56877936,39531571.87346303,18438045.1915348,22887086.75795797,56585717.86213812,50222553.77015964,50920464.18260706,39077419.43175923,82908337.24285261,55706222.98825989,42049195.31907591,52883604.40812992,55694986.55506849,100637201.48995867,47660257.32368384,50223219.26876998,15653759.333181392,29981429.34524077,74749063.00510815,48880730.61052807,37358721.14159041,42123185.21263974,31277205.745097827,31199487.449541032,61325294.369610585,53070843.28056764,43150157.85978441,31891756.29583592,22552570.362558786,8018626.3 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d2525175-d595-4f4f-b529-63d72756f105" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2525175-d595-4f4f-b529-63d72756f105")) {                    Plotly.newPlot(                        "d2525175-d595-4f4f-b529-63d72756f105",                        [{"hovertemplate":"date=%{x}\u003cbr\u003etvlUSD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[86568439.17063099,87506244.4465829,92841931.86480938,92899910.49674264,95014607.40021735,91290114.48629144,92388431.18509738,92714541.64776972,91207619.43682584,93490822.91063842,95181710.19190855,89376809.87611584,101014663.347373,96548762.5626828,89376776.11782123,115892041.56467752,75413190.62958355,100852490.53827624,111930365.28532083,117010901.74563617,119917046.86084732,118377382.9129592,115482202.14912836,119855937.90629528,114220785.8994316,110004871.41314116,96253314.26709916,93893446.06845224,93900912.73357087,95311338.63062124,95698214.30465344,93852079.74931692,95444189.1041428,94908180.08910136,98800924.43853883,96525285.51560289,96249421.27453232,97922519.6925738,99313201.26386672,101605734.8733459,101304182.02864908,99607828.15943933,99778201.63531986,96070233.2123349,90687662.25918798,90001958.5891802,91107899.01549783,94033552.60402794,90283607.81635642,90726686.91898432,90126379.98143598,89783920.55571544,80858640.3497001,61680539.21392617,60742779.52725914,63882361.336762056,60729674.23647657,63428255.73999224,64874605.900596455,63863672.800911166,64599380.78577089,63277579.843613,63084277.52168839,63091547.45114861,63246116.031282,63648669.80 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e89fa48a-65b6-403f-9705-becfa3a25761" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e89fa48a-65b6-403f-9705-becfa3a25761")) {                    Plotly.newPlot(                        "e89fa48a-65b6-403f-9705-becfa3a25761",                        [{"hovertemplate":"date=%{x}\u003cbr\u003efeesUSD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[49255.06281653078,46771.051952089205,18482.280210386874,20157.367141436647,59434.59862539389,49720.785747921895,22384.29764329927,20063.189736992143,53641.22684658064,27285.77307023308,43357.56520803229,60948.90266842646,100719.88135409122,55749.0917000672,61288.68505885405,142780.93711881468,38692.0525517484,100974.81154238831,76293.40674032089,99714.89622518046,60761.76142959356,55103.16182770242,94224.24262153512,32608.44065409649,71298.94024561133,138518.96368193167,104047.7062422895,71323.55856259893,48827.09127662892,26661.029972277545,13352.250014036224,20721.26014901671,21118.12542212492,23011.36989484797,42229.687050149405,27684.76378438968,19765.78593673151,9219.0225957674,11443.543378978984,28292.85893106906,25111.27688507982,25460.23209130353,19538.709715879617,41454.1686214263,27853.111494129946,21024.59765953795,26441.80220406496,27847.49327753425,50318.60074497935,23830.12866184192,25111.60963438499,7826.879666590696,14990.714672620386,37374.53150255407,24440.365305264037,18679.360570795205,21061.59260631987,15638.602872548914,15599.743724770517,30662.647184805293,26535.42164028382,21575.078929892203,15945.87814791796,11276.285181279392,4009.31318 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d65d95d7-39de-4240-b5dd-f70af6217706" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d65d95d7-39de-4240-b5dd-f70af6217706")) {                    Plotly.newPlot(                        "d65d95d7-39de-4240-b5dd-f70af6217706",                        [{"hovertemplate":"date=%{x}\u003cbr\u003eliquidity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[3454815445125479796,3498938222014558006,4013935148038119716,4152118352609354917,16960299443963621544,2220114899629689056,2512427471453838509,2272434627468156425,2369353689750415794,2556843603610275613,2199107047252240789,1488012218572281558,2898205124073278340,732852735168402597,3349132797984123243,2673263148020154294,5778110647463289069,2554653418769203235,2133929804060603100,3074412271793160249,3101211665517478732,3093579107256426814,3485144164501584075,3098698253497051733,4166448333095350499,1998642151276510978,3835952907848070036,3507295432144600296,3730607026329630678,3570447807597285572,3610084616744105722,2731962010819480064,3665757917302331078,3634373060797474081,3631148664722266201,3642386383791549773,3618222159511945903,3761885939198496032,3875706640543190363,3886318242397383491,3886866299487069270,3886298489529703136,3991956870961414452,2994328203780120257,2735927846469066541,2780861221559322589,2829214369652312261,3725449549218474268,1287555600174678879,2822075276644464026,2734894855903989666,2734395495116389824,211290624383688295,3640634973314150069,186079822095980238,737130927256040689,912993793688249087,1022501797186527986,2215446042505132986,16 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b66fc6c7-befb-4927-8313-ada8b7a246bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b66fc6c7-befb-4927-8313-ada8b7a246bd")) {                    Plotly.newPlot(                        "b66fc6c7-befb-4927-8313-ada8b7a246bd",                        [{"hovertemplate":"date=%{x}\u003cbr\u003eliquidity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[214025029851676315,233269344574293471,214579361171783400,229551249703581715,146076942356605427,218942599349364438,158257135875242621,259773298020782991,204441059919524098,142759291980350904,135722163390254264,178076962929529665,154070345486201608,198720770097415271,198815747161272958,170518386592197489,179652106308774408,204287941431183356,135862739995161845,135747088177817914,135628346101941390,162047680640454455,162062784388423970,272226681186310767,269123560007385943,158081930368128296,81905504757089701,51571296992948570,187112335204086279,118105417673931287,176755705410356095,107349165566429537,107510731707921411,246734399075936027,245706531745831751,245822854823599227,246180485924732775,234168728304286750,234766066755281224,237965193359771240,236177266053893092,239682561535176937,165798387345182699,40177170236693525,20822820659222712,18311557311497211,19956505425256815,38042516421041551,17827537162224109,48192394165277746,48146368124614383,49520979380903050,13570584653070301,22974170514444885,24636841468615512,61216504507016953,78309348535068667,77459706698898585,71090207821558933,71258765449174935,71344700496133393,117837694968341002,122882419158150968,1 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="658a1ae6-df0c-4091-af40-4bf4a33dde75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("658a1ae6-df0c-4091-af40-4bf4a33dde75")) {                    Plotly.newPlot(                        "658a1ae6-df0c-4091-af40-4bf4a33dde75",                        [{"hovertemplate":"date=%{x}\u003cbr\u003etoken0Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[0.0277118399828338,0.0279788277958835,0.0276409839832575,0.0276979210511516,0.0286788355788854,0.0279941938780226,0.0281629365802975,0.0279209852623559,0.0277044686407187,0.0286701296811998,0.029311289061128,0.0274487827214956,0.0281750393169702,0.0277700447570712,0.02726245615695,0.0265542096880984,0.0258157045531971,0.0267922914924992,0.0249586534007726,0.024932159953682,0.0247840858271051,0.0245316919297763,0.0246982375084136,0.0255848255624943,0.0250530395788943,0.0237498797248652,0.0232378371746946,0.0228409320989488,0.0230322718250877,0.0227947645753776,0.0230288803076596,0.0228910123945351,0.0229903519510402,0.0233950415828055,0.0237542705045209,0.0235836079693452,0.0234099310362548,0.0236428875623499,0.0233399347520437,0.0238061835792712,0.0236865747226054,0.0231587218225323,0.0230049251825418,0.022502783347439,0.0221399128062564,0.02195615227574,0.0221036681507666,0.0223996467912011,0.0217731969990258,0.0218747376199182,0.021655492766447,0.0216500449563857,0.0202036765518898,0.019666169785252,0.0193195767115667,0.0202185171918542,0.0191267078518904,0.0187973580002233,0.0192773653014393,0.0190764242908915,0.0192011491937375,0.0189893047580148,0.01877 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e0c13bd1-e452-4472-8b7f-3e785b24362a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0c13bd1-e452-4472-8b7f-3e785b24362a")) {                    Plotly.newPlot(                        "e0c13bd1-e452-4472-8b7f-3e785b24362a",                        [{"hovertemplate":"date=%{x}\u003cbr\u003etoken1Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00"],"xaxis":"x","y":[36.08565871553281,35.741311512240195,36.1781621307588,36.1037927053525,34.86891918081364,35.721693018103544,35.50766082751426,35.81535503148009,36.095260045169965,34.8795073869422,34.11654799331822,36.43148806073951,35.49240832461541,36.01002478562317,36.68048081372407,37.658812359540754,38.73611111172078,37.324168419112574,40.06626415065494,40.10883942096306,40.34847228080326,40.76359685514425,40.48871906990692,39.08566808702156,39.91531633720157,42.10547638913037,43.03326477771224,43.78105042595974,43.4173410071843,43.86972265904319,43.423735181227535,43.68526750868967,43.49650680118241,42.74410013166904,42.09769354144885,42.40233306540001,42.71691353773332,42.29601808843557,42.84502123179392,42.00589299289154,42.21800795222801,43.18027599550184,43.46895249887136,44.438947154233,45.16729621976712,45.54532084863183,45.24135963221632,44.64356109368716,45.92802793474651,45.71483404168662,46.17766082651308,46.18928053103403,49.49594186145583,50.84874232856025,51.760968417144106,49.45961123216729,52.282912864231456,53.19896551356416,51.87430877420453,52.42072543319736,52.08021613238376,52.66122234295737,53.27199863955805,53.62885539493161,53.12942891137795,52.7 ...
